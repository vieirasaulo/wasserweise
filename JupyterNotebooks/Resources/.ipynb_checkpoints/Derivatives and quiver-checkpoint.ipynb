# %% [markdown]
# # Gradients and quiver

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sympy import *
import json
import geojsoncontour
import folium
import geopandas as gpd
from pyproj import Geod

import sys
import os
import pandas as pd
import geopandas as gpd
from scipy.interpolate import griddata

path = 'd:/repos/pirnacasestudy'
sys.path.append('d:/repos/pirnacasestudy')
import SmartControl as sc

os.chdir(path)
Get = sc.queries.Get('Data/database.db')

# %%
plt.rcParams["figure.figsize"] = (10, 5) # set default figure size
plt.rcParams["contour.negative_linestyle"] = 'solid' # set default line style
plt.rcParams["figure.autolayout"] = True # same as tight_layout after every plot

# %%
date_wid = pd.to_datetime('2022/12/12 12')

map_gdf = sc.utils.prepare_query (Get, date_wid )
grid_x_gcs , grid_y_gcs , grid_z_gcs, U , V = sc.utils.Interpolation_Gradient (map_gdf , crs_utm = 25833 , pixel_size = 10)

map_center = map_gdf.N.mean(), map_gdf.E.mean() #in folium y comes before x

m = folium.Map(location = map_center, zoom_start=15)

arrows_df = sc.utils.arrow_head (grid_x_gcs , grid_y_gcs , grid_z_gcs, U , V)
sc.utils.Folium_arrows(m , arrows_df )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61951e8cd7002a22ee53284142b86b91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61951e8cd7002a22ee53284142b86b91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_61951e8cd7002a22ee53284142b86b91 = L.map(
#                 &quot;map_61951e8cd7002a22ee53284142b86b91&quot;,
#                 {
#                     center: [50.965212961636894, 13.924112067842753],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5a7cca31799d58a22521cb405d5b876 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_61951e8cd7002a22ee53284142b86b91);
#
#
#             var poly_line_2cbf0768f66df019d8793a5ae43977b6 = L.polyline(
#                 [[50.964732971904766, 13.92192150601613], [50.96473342577392, 13.921917606653217]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_61951e8cd7002a22ee53284142b86b91);
#
#
#             var regular_polygon_marker_d2db7f8eb34aac226727d29f5b34cecf = new L.RegularPolygonMarker(
#                 [50.96473342577392, 13.921917606653217],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;rotation&quot;: 10.44362092034946, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_61951e8cd7002a22ee53284142b86b91);
#
#
#             var poly_line_b96f9d1a5d93a548d928d512812a910a = L.polyline(
#                 [[50.96482750285715, 13.92192150601613], [50.964829051168955, 13.921914425358619]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_61951e8cd7002a22ee53284142b86b91);
#
#
#             var regular_polygon_marker_7e4ebb32a9c08fadafa8b66cb8d7677b = new L.RegularPolygonMarker(
#                 [50.964829051168955, 13.921914425358619],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;rotation&quot;: 19.09982994440415, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_61951e8cd7002a22ee53284142b86b91);
#
#
#             var poly_line_9080ad1ba9c222ede5c8492a234d879f = L.polyline(
#                 [[50.96492203380953, 13.92192150601613], [50.96492471108538, 13.921910707532309]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_61951e8cd7002a22ee53284142b86b91);
#
#
#             var regular_polygon_marker_829d56a553a997750cab10afe421e2e5 = new L.RegularPolygonMarker(
#                 [50.96492471108538, 13.921910707532309],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArra

# %% [markdown]
# ## 1. 1D numpy grad

# %% [markdown]
# 1. Suppose we have two points and we want to get the derivative or gradient

# %%
x = np.array( [ 10 , 100 ] ) # x coordinates
y = np.array ( [ 30, 100 ] ) # y coordinates

#size 1 
def grad (x,y, s):
    dx = np.gradient(x, s)
    dy = np.gradient (y, s)
    print (f'The gradient of x and y is: {dx}, {dy} for space {s}')

for i in range(5):
    grad(x,y,i+1)
# Out:
# The gradient of x and y is: [90. 90.], [70. 70.] for space 1
# The gradient of x and y is: [45. 45.], [35. 35.] for space 2
# The gradient of x and y is: [30. 30.], [23.33333333 23.33333333] for space 3
# The gradient of x and y is: [22.5 22.5], [17.5 17.5] for space 4
# The gradient of x and y is: [18. 18.], [14. 14.] for space 5

# %% [markdown]
# If we add the third element, we see:
#
# $$  dx_0 = x_1 - x_2 $$
#
# $$ dx_1 = \frac {(x_2 - x_0 )}{2} $$
#
# * and the division by two of inner element it is because it jumps over the position one and goes to position two to calculate the gradient exatcly at the position 1. Because the distance is now twice as big, if the array is uniform, then the gradient is half of that.
#
# $$ dx_2 = x_2 - x_1 $$

# %% [markdown]
# If the **edge order** is set as default, which is  **1**, then we see the edge is the exact difference between the bordering elements.

# %%
x = np.array( [ 10 , 100 , 150] ) # x coordinates
y = np.array ( [ 30, 100 , 160 ] ) # y coordinates

for i in range(5):
    grad(x,y,i+1)
# Out:
# The gradient of x and y is: [90. 70. 50.], [70. 65. 60.] for space 1
# The gradient of x and y is: [45. 35. 25.], [35.  32.5 30. ] for space 2
# The gradient of x and y is: [30.         23.33333333 16.66666667], [23.33333333 21.66666667 20.        ] for space 3
# The gradient of x and y is: [22.5 17.5 12.5], [17.5  16.25 15.  ] for space 4
# The gradient of x and y is: [18. 14. 10.], [14. 13. 12.] for space 5

# %% [markdown]
# Test edge order. What does it do?
#
# **What if we increase the edge ?**

# %%
#size 1 
def grad (x,y ):
    dx = np.gradient(x, edge_order = 2)
    dy = np.gradient (y, edge_order = 2)
    print (f'The gradient of x and y is: {dx}, {dy} for edge = 2')


grad(x,y)
# Out:
# The gradient of x and y is: [110.  70.  30.], [75. 65. 55.] for edge = 2

# %% [markdown]
# * We see that the edge order is an **extrapolation** of the gradient.
# * It increases or decreases the values based on the inner derivatives.
# * In this example, the border is $ d_0 = d_1 - d_0 $, but it is:
# $$ dx_0 = x_1 - x_0 \pm (dx_1 - dx_0) $$

# %% [markdown]
# * We see that if we grow the space/ distance in between the elements of our array, the derivative/slope/gradient obviously decreases.
#
# * The space is therefore the distance between the point at the axis where we are computing the derivative
#
# **Let's add a new dimension to the problem and see:**
#
# **What happens if we apply the real space?**

# %%
z = np.array ( [ 100, 105 ] ) 

def graddz_dx(z, x):
    dz = np.gradient (z, x)
    print (f'The partial gradient of z is: {dz}, for spacing {x}')
graddz_dx(z, x)
# Out:
# The partial gradient of z is: [0.05555556 0.05555556], for spacing [ 10 100]

# %%
# comparison
dx = x[1] - x[0]
dz = z[1]- z[0]
grad = dz / dx
print (f'The gradient is: {grad}')
# Out:
# The gradient is: 0.05555555555555555

# %% [markdown]
# ## 2. 1d problems along the x axis

# %%
x = Symbol('x')
f = x**2
df_dx = diff(f, x)
f1 = lambdify (x, f)

# %%
x_arr = np.linspace(0,100, 101)

x = Symbol ('x')
f = x_**2
s_dz_dx = diff(f, x) #symbol of analytical derivative

fz = lambdify(x, f) # function f was attributed to the Z dimension
z = fz(x_arr) 

s_dz_dx
# Out:
# 2*x

# %%
def edge_order (o):

    '''
    Numerical
    '''
    num_dz = np.gradient(z, x_arr, edge_order = o)#numerical derivative = gradient

    '''
    Analytical
    '''
    dz_dx = 2*x_arr #function of derivative



    '''
    Plotting

    '''

    plt.subplot(221)
    plt.plot(x_arr, z, color = 'b', label = '$x^2$')
    plt.plot (x_arr, num_dz , color = 'g' , label = r'Gradient $\frac{d_z}{d_x}$')
    plt.grid()
    plt.title(f'Edge order = {o}')
    plt.xlabel('$x$ (m)')
    plt.ylabel('$z$ (m)')
    plt.legend()

    plt.subplot(222)
    plt.plot (x_arr, num_dz , color = 'g' , label = r'Gradient  $\frac{d_z}{d_x}$')
    plt.plot (x_arr, dz_dx , color = 'r' , label = r'Derivative : $2 \cdot x$')
    plt.grid()
    plt.xlabel('$x$ (m)')
    plt.title(f'Edge order = {o}')
    plt.ylabel('$z$ (m)')
    plt.legend()
    plt.show()


    plt.subplot(2,2,3)

    z_ = num_dz - dz_dx

    plt.plot (x_arr, z_ , color = 'g' , label = r'$ \frac{\frac{d_z}{d_x}}{2 \cdot x}$')
    plt.grid()
    plt.xlabel('$x$ (m)')
    plt.ylabel('$z$ (m)')
    plt.title(f'Edge order = {o}')
    plt.legend()
    
    return plt.show()

# %%
edge_order (1)

# %%
edge_order (2)

# %% [markdown]
# **We can see that the numpy.gradient accurately computes the derivative**

# %% [markdown]
# let us think about heads in one horizon now

# %%
x = np.linspace(1,10,10)
x = np.power(x,2) #space in x is growing
np.random.seed(30)
h = np.random.randint(100, 110, 10) #heads

grad_i = np.gradient(h, x) # hydraulic gradient over x

plt.subplot(121)
plt.plot (x, h , color = 'b' , label = 'Hydraulic head along x')
plt.plot (x, grad_i , color = 'r' , label = 'hydraulic gradient')
plt.grid()
plt.xlabel('$x$ (m)')
plt.ylabel('$h$ (m)')
plt.legend()

plt.subplot(122)
plt.plot (x, grad_i , color = 'r' , label = 'hydraulic gradient')
plt.grid()
plt.xlabel('$x$ (m)')
plt.ylabel('$h$ (m)')
plt.legend()
plt.show()

# %%
x_list = list(np.diff(x))
x_list.append(21.)
x_quiver = np.array(x_list)


h_list = list(np.diff(h))
h_list.append(1.)
h_quiver = np.array(h_list)

# %%
plt.subplot(121)
plt.plot (x, h , color = 'b' , label = 'Hydraulic head along x')
plt.quiver(x, h, x_quiver, h_quiver, angles = 'xy' , label = 'hydraulic head direction')
plt.grid()
plt.xlabel('$x$ (m)')
plt.ylabel('$h$ (m)')
plt.legend()


plt.show()

# %% [markdown]
# ## 3. 2D Problem with groundwater heads

# %%
import sys
import os
import pandas as pd
import geopandas as gpd
from scipy.interpolate import griddata

path = 'd:/repos/pirnacasestudy'
sys.path.append('d:/repos/pirnacasestudy')
import SmartControl as sc

os.chdir(path)
Get = sc.queries.Get('Data/database.db')

# %%
crs = 4326
res = 10 # 5 meters
dst_crs = 'EPSG:25833'

date_wid = pd.to_datetime('2022/12/12 12')

Get.Isolines(Year = pd.to_datetime(date_wid.value).year,
                  Month = pd.to_datetime(date_wid.value).month,
                  Day = pd.to_datetime(date_wid.value).day,
                  Hour = pd.to_datetime(date_wid.value).hour)

df  = Get.Isolines_df.copy()

df = df.dropna()

df_ = sc.utils.ControlPoints()
df = sc.utils.BoundaryCondition(df, df_).reset_index(drop = True)

df.loc [df.MonitoringPointName.str.len()>4 , 'cut'] = 1
df.loc [df.MonitoringPointName.str.len() <= 4 , 'cut'] = 0
gwms_mean = df[df.cut == 1].Value.mean()
df = df [~ df.index.isin (df[df.cut == 1].index[1:])]
df.loc [df.cut == 1, 'Value'] = gwms_mean
df = df.drop('cut', axis =1)

map_df = df.copy()
map_gdf = gpd.GeoDataFrame(map_df, geometry = gpd.points_from_xy (map_df.E, map_df.N), crs = crs).reset_index(drop = True)

'''
folium elements

'''

# Create a geometry list from the GeoDataFrame to pass into folium map
points_list = [list(i[1].values) for i in map_gdf[['N', 'E']].iterrows()]
map_center = map_gdf.N.mean(), map_gdf.E.mean() #in folium y comes before x

'''
Gradient
'''

# 1. convert it to utm to get a real gradient

map_gdf = map_gdf.to_crs(dst_crs)


# 2. Linear interpolation 

# 2.1 fetching converted points
points = np.array( pd.DataFrame ( 
                    {
                        'x' : map_gdf.geometry.x ,
                        'y' : map_gdf.geometry.y
                    }
                                 )
                 )


# points = np.array(map_df[['E','N']])


# 2.2 Fetching values
values = np.array(map_df.Value)

# 2.3 preparing the grids
minx, maxx = map_gdf.geometry.x.min(), map_gdf.geometry.x.max()
miny, maxy = map_gdf.geometry.y.min(), map_gdf.geometry.y.max()

grid_x , grid_y = np.mgrid [minx:maxx:res, miny:maxy:res]  


# 2.4 interpolating
grid_z = griddata(points, values, (grid_x, grid_y), method='cubic')

u, v = np.gradient(grid_z, res)

#increase the scale of the plot
U =  - u 
V =  - v 

x = grid_x
y = grid_y


fig, ax = plt.subplots()

# kw = dict(color='black', alpha=0.1, scale=1)
contour = plt.contour(grid_x, grid_y, grid_z, linewidths = 2)
plt.colorbar()

q = ax.quiver(x, y, U, V)

# %% [markdown]
# ### 2.1 Confirming that the gradient indeed represents the right value

# %%
grid_x , grid_y = np.mgrid [1:11:1, 1:11:1]  

grid_z = np.linspace(118, 100, 10)
arrays = [grid_z for _ in range(10)]

grid_z = np.stack(arrays, axis = 0)

u, v = np.gradient(grid_z, 1)

#increase the scale of the plot
U =  - u 
V =  - v 

x = grid_x
y = grid_y



contour = plt.contour(grid_x, grid_y, grid_z, linewidths = 2)
plt.colorbar()

# kw = dict(color='black', alpha=0.8, scale=10)
q = plt.quiver(x, y, U, V)
plt.show()

# %% [markdown]
# 1. The grid in the y direction varies has a resolution of 1 m

# %% [markdown]
# 2. The head values vary constantly (constant derivative or gradient) only in the y direction. They are equal 2
#
# **These values can indeed be interpreted as groundwater heads**
#
#
# **Useful links about gradient and grids using numpy**
#
# [mgrid vs-meshgrid](http://louistiao.me/posts/numpy-mgrid-vs-meshgrid/)
#
# [groundwater analytical modelling](https://github.com/pythongroundwaterbook/analytic_gw_book/blob/main/chapter1/chapter1_bakker_post.ipynb)
#
# [explaining complicated gradients](https://stackoverflow.com/questions/17901363/gradient-calculation-with-python)

# %% [markdown]
# ## 4. Prepare to plot it in Folium

# %%
crs = 4326
res = 10 # 5 meters
dst_crs = 'EPSG:25833'

date_wid = pd.to_datetime('2022/12/12 12')

Get.Isolines(Year = pd.to_datetime(date_wid.value).year,
                  Month = pd.to_datetime(date_wid.value).month,
                  Day = pd.to_datetime(date_wid.value).day,
                  Hour = pd.to_datetime(date_wid.value).hour)

df  = Get.Isolines_df.copy()

df = df.dropna()

df_ = sc.utils.ControlPoints()
df = sc.utils.BoundaryCondition(df, df_).reset_index(drop = True)

df.loc [df.MonitoringPointName.str.len()>4 , 'cut'] = 1
df.loc [df.MonitoringPointName.str.len() <= 4 , 'cut'] = 0
gwms_mean = df[df.cut == 1].Value.mean()
df = df [~ df.index.isin (df[df.cut == 1].index[1:])]
df.loc [df.cut == 1, 'Value'] = gwms_mean
df = df.drop('cut', axis =1)

map_df = df.copy()
map_gdf = gpd.GeoDataFrame(map_df, geometry = gpd.points_from_xy (map_df.E, map_df.N), crs = crs).reset_index(drop = True)

'''
folium elements

'''

# Create a geometry list from the GeoDataFrame to pass into folium map
# points_list = [list(i[1].values) for i in map_gdf[['N', 'E']].iterrows()]
map_center = map_gdf.N.mean(), map_gdf.E.mean() #in folium y comes before x

'''
Gradient
'''

# 1. convert it to utm to get a real gradient

map_gdf = map_gdf.to_crs(dst_crs)


# 2. Linear interpolation 

# 2.1 fetching converted points
points_utm = np.array( pd.DataFrame ( 
                    {
                        'x' : map_gdf.geometry.x ,
                        'y' : map_gdf.geometry.y
                    }
                                 )
                 )


points_gcs = np.array(map_df[['E','N']])


# 2.2 Fetching values
values = np.array(map_gdf.Value)

# 2.3 preparing the grids

#grid utm
minx, maxx = map_gdf.geometry.x.min(), map_gdf.geometry.x.max()
miny, maxy = map_gdf.geometry.y.min(), map_gdf.geometry.y.max()
grid_x_utm , grid_y_utm = np.mgrid [minx:maxx:res, miny:maxy:res]  

# #grid gcs
minx, maxx = map_gdf.E.min(), map_gdf.E.max()
miny, maxy = map_gdf.N.min(), map_gdf.N.max()
xx = np.linspace(minx, maxx,grid_x_utm.shape[0] )
yy = np.linspace(miny, maxy,grid_x_utm.shape[1] )
grid_x_gcs_ , grid_y_gcs_ = np.meshgrid(xx, yy)

grid_x_gcs, grid_y_gcs = grid_x_gcs_.T , grid_y_gcs_.T


# 2.4 interpolating - we're plotting only gcs 4326
# grid_z_gcs  = griddata(points_gcs, values, (grid_x_gcs, grid_y_gcs), method='cubic')
grid_z = griddata(points_utm, values, (grid_x_utm, grid_y_utm), method='cubic')




# 2.5 calculating the gradient - only for utm
u, v = np.gradient(grid_z_utm, res)


'''
Plotting
'''
U =  - u 
V =  - v 

x = grid_x_gcs
y = grid_y_gcs


fig, ax = plt.subplots()
# kw = dict(color='black', alpha=0.1, scale=1)
contour = plt.contour(x, y, grid_z_gcs, linewidths = 2)
plt.colorbar()
plt.title('Plot in GCS EPSG : 4236 and gradient calculated in m')
q = ax.quiver(x, y, U, V)

# %% [markdown]
# it worked! but small problem with signals and orientation

# %% [markdown]
# ## Folium

# %%
df = pd.DataFrame ( {
    'x' : grid_x_gcs.ravel(),
    'y' : grid_y_gcs.ravel(),
    'h' : grid_z.ravel() , 
    'u' : - u.ravel(),
    'v' : - v.ravel()
               }
             )

df ['u_coord'] = df.x + df.u / 5e2
df ['v_coord'] = df.y + df.v / 5e2
df [ ~ df.u_coord.isna() ]
df = df.dropna().reset_index(drop = True)

# plt.scatter(df.x , df.y , c = df.h)
# plt.colorbar()

loc = [list(i[1].values) for i in df[['y', 'x']].iterrows()]

uv = [list(i[1].values) for i in df[['v_coord', 'u_coord']].iterrows()]

pairs = [(loc[i], uv[i]) for i,_  in enumerate(loc) ]

geodesic = Geod(ellps='WGS84')
rotations = [geodesic.inv(pair[0][1], pair[0][0], pair[1][1], pair[1][0])[0]-90 for pair in pairs]

df [ 'rotation'] = rotations

m = folium.Map(location = map_center, zoom_start=15)

for i in range(df.shape[0]):
    #DFW, LGA coordinates

    coordinates=[(df['y'][i], df['x'][i]), (df['v_coord'][i] , df['u_coord'][i] )]    

    aline=folium.PolyLine(
        locations = coordinates,
        weight = 2,
        color = 'black'
                         )
    m.add_child(aline)
    

    folium.RegularPolygonMarker(location= (df['v_coord'][i] , df['u_coord'][i] ),
                                    color='black',
                                    fill = True,
                                    fill_color='black',
                                    fill_opacity = 1 ,
                                    number_of_sides=3,
                                    radius = 1,
                                    rotation= df['rotation'][i] ).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_213a3c424a19afae3d190a7895574f2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_213a3c424a19afae3d190a7895574f2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_213a3c424a19afae3d190a7895574f2b = L.map(
#                 &quot;map_213a3c424a19afae3d190a7895574f2b&quot;,
#                 {
#                     center: [50.965212961636894, 13.924112067842753],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34b953833ca00f3c4792cf281935ce44 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_213a3c424a19afae3d190a7895574f2b);
#
#
#             var poly_line_4fee14af3a7223b877904d641d4036c4 = L.polyline(
#                 [[50.964732971904766, 13.92192150601613], [50.96473251803561, 13.921925405379042]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_213a3c424a19afae3d190a7895574f2b);
#
#
#             var regular_polygon_marker_97e7ed89fbfbc1529b0c79c88f03e60d = new L.RegularPolygonMarker(
#                 [50.96473251803561, 13.921925405379042],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;rotation&quot;: 10.44362106553875, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_213a3c424a19afae3d190a7895574f2b);
#
#
#             var poly_line_aec5ca1926d2571a7e6bde6c6a02efb4 = L.polyline(
#                 [[50.96482750285715, 13.92192150601613], [50.96482595454534, 13.92192858667364]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_213a3c424a19afae3d190a7895574f2b);
#
#
#             var regular_polygon_marker_53ec1b919583d93ff22f589955fd3cb7 = new L.RegularPolygonMarker(
#                 [50.96482595454534, 13.92192858667364],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;rotation&quot;: 19.099829186898376, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_213a3c424a19afae3d190a7895574f2b);
#
#
#             var poly_line_81e0d7360bf86ef99f076af5e9adb74a = L.polyline(
#                 [[50.96492203380953, 13.92192150601613], [50.96491935653368, 13.92193230449995]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_213a3c424a19afae3d190a7895574f2b);
#
#
#             var regular_polygon_marker_779f30abf589b70352deb4e66bb55991 = new L.RegularPolygonMarker(
#                 [50.96491935653368, 13.92193230449995],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quo

# %%
map_gdf = sc.utils.prepare_query (Get, date_wid )
grid_x_gcs , grid_y_gcs , grid_z_gcs, U , V = sc.utils.Interpolation_Gradient (map_gdf , crs_utm = 25833 , pixel_size = 10)

m = folium.Map(location = map_center, zoom_start=15)

arrows_df = sc.utils.arrow_head (grid_x_gcs , grid_y_gcs , grid_z_gcs, U , V)
sc.utils.Folium_arrows(m , arrows_df )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a203f69dac9ee2dabad6866dacc3cc2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a203f69dac9ee2dabad6866dacc3cc2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2a203f69dac9ee2dabad6866dacc3cc2 = L.map(
#                 &quot;map_2a203f69dac9ee2dabad6866dacc3cc2&quot;,
#                 {
#                     center: [50.965212961636894, 13.924112067842753],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e870ad8ffbc4fb1b0ab3940c24b4a58 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2a203f69dac9ee2dabad6866dacc3cc2);
#
#
#             var poly_line_78b0cc7af8c93bf1521211568b4da51e = L.polyline(
#                 [[50.964732971904766, 13.92192150601613], [50.96473342577392, 13.921917606653217]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_2a203f69dac9ee2dabad6866dacc3cc2);
#
#
#             var regular_polygon_marker_553a68245c8f8367e812bdacf7dd8a3e = new L.RegularPolygonMarker(
#                 [50.96473342577392, 13.921917606653217],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;rotation&quot;: 10.44362092034946, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2a203f69dac9ee2dabad6866dacc3cc2);
#
#
#             var poly_line_b3f025bb3371fde448acead849f28cff = L.polyline(
#                 [[50.96482750285715, 13.92192150601613], [50.964829051168955, 13.921914425358619]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_2a203f69dac9ee2dabad6866dacc3cc2);
#
#
#             var regular_polygon_marker_a469d4d91e93f56a8afc91089a673219 = new L.RegularPolygonMarker(
#                 [50.964829051168955, 13.921914425358619],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;rotation&quot;: 19.09982994440415, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2a203f69dac9ee2dabad6866dacc3cc2);
#
#
#             var poly_line_a0efc242102b1179278e217c841d0364 = L.polyline(
#                 [[50.96492203380953, 13.92192150601613], [50.96492471108538, 13.921910707532309]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_2a203f69dac9ee2dabad6866dacc3cc2);
#
#
#             var regular_polygon_marker_22954aecd588a1030536422f1d2c6718 = new L.RegularPolygonMarker(
#                 [50.96492471108538, 13.921910707532309],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArra
